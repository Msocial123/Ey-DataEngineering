# %%
#Distributed Data 
#Data--> anytype -->Structured data:RDBMS name(varchar),age(int),salary(float)-->insert into  values('2murali',42,12.022)\
                #-->semi structure:nosql,Json,Auro,parquet,orc,hive
                #unstructure :.txt,.csv.tsv
                #df

# %%
#RDD --> core for Spark
#logic sql syntax format  sql engine --> sql funnctional program
#spar sql(engine):
    #
#operations: sql syntaxes
#SCHEMA DATA=SCHEMA RDD =DATA FRAMES = FORM OF ROWS
# every RDD is a dataframe 
#every data frame is not RDD
# earlier (spark confi + SparContext +SqlCOntext )=SparkSession

# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.appName("").master("local[3]").getOrCreate()

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://DATA-AWS:4041">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.7</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[3]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code></code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
employee = spark.read.json(r"C:\Users\user1\pyspark_env\employee.json")

# %%
type(employee)
# Out:
# pyspark.sql.dataframe.DataFrame

# %%
employee.printSchema()
# Out:
# root
#  |-- _corrupt_record: string (nullable = true)

# %%
employee.columns
# Out:
# ['_corrupt_record']

# %%
employee = spark.read.json(r"C:\Users\user1\pyspark_env\employee.json")

# %%
employee_D = spark.read.json(r"C:\Users\user1\pyspark_env\employees_data.json")

# %%
type(employee_D)
# Out:
# pyspark.sql.dataframe.DataFrame

# %%
employee_D.printSchema()
# Out:
# root
#  |-- _corrupt_record: string (nullable = true)
#  |-- department: string (nullable = true)
#  |-- emp_id: long (nullable = true)
#  |-- emp_name: string (nullable = true)
#  |-- salary: long (nullable = true)

# %%
employee_D.columns
# Out:
# ['_corrupt_record', 'department', 'emp_id', 'emp_name', 'salary']

# %%
employee_D.schema
# Out:
# StructType([StructField('_corrupt_record', StringType(), True), StructField('department', StringType(), True), StructField('emp_id', LongType(), True), StructField('emp_name', StringType(), True), StructField('salary', LongType(), True)])

# %%
employee_D.show()
# Out:
# +---------------+----------+------+--------+------+
# |_corrupt_record|department|emp_id|emp_name|salary|
# +---------------+----------+------+--------+------+
# |              [|      NULL|  NULL|    NULL|  NULL|
# |           NULL|        IT|   201|     Raj| 65000|
# |           NULL|   Finance|   202|   Meena| 58000|
# |           NULL|        HR|   203|   Kiran| 60000|
# |              ]|      NULL|  NULL|    NULL|  NULL|
# +---------------+----------+------+--------+------+

# %%
employee_D.collect()
# Out:
# [Row(_corrupt_record='[', department=None, emp_id=None, emp_name=None, salary=None),
#  Row(_corrupt_record=None, department='IT', emp_id=201, emp_name='Raj', salary=65000),
#  Row(_corrupt_record=None, department='Finance', emp_id=202, emp_name='Meena', salary=58000),
#  Row(_corrupt_record=None, department='HR', emp_id=203, emp_name='Kiran', salary=60000),
#  Row(_corrupt_record=']', department=None, emp_id=None, emp_name=None, salary=None)]

# %%
employee_D = spark.read.format('json').load(r"C:\Users\user1\pyspark_env\employees_data.json")

# %%
type(employee_D)
# Out:
# pyspark.sql.dataframe.DataFrame

# %%
sales = spark.read.format('csv').load(r"C:\Users\user1\pyspark_env\sales_data_clean.csv")

# %%
sales.spark.read.format('csv').load(r"C:\Users\user1\pyspark_env\sales_data_clean.csv")

# %%
sales.show()
# Out:
# +-------+----------+------+--------+--------+----------+-----------+
# |    _c0|       _c1|   _c2|     _c3|     _c4|       _c5|        _c6|
# +-------+----------+------+--------+--------+----------+-----------+
# |sale_id|      date|region| product|quantity|unit_price|total_sales|
# |      1|2025-01-02|  East| Monitor|       8|  42106.76|  336854.08|
# |      2|2025-01-03|  East|   Mouse|       3|   7448.26|   22344.78|
# |      3|2025-01-04|  East| Printer|       4|  10429.24|   41716.96|
# |      4|2025-01-05|  East| Printer|       2|  50678.91|  101357.82|
# |      5|2025-01-06| South|   Mouse|       5|  43414.96|   217074.8|
# |      6|2025-01-07| South| Printer|       9|  20740.43|  186663.87|
# |      7|2025-01-08|  East|   Mouse|       3|  27081.11|   81243.33|
# |      8|2025-01-09|  West|  Laptop|       3|  60265.86|  180797.58|
# |      9|2025-01-10|  East| Printer|       9|   5021.09|   45189.81|
# |     10|2025-01-11|  West|  Laptop|       2|  27286.45|    54572.9|
# ...

# %%
sales.printSchema()
# Out:
# root
#  |-- _c0: string (nullable = true)
#  |-- _c1: string (nullable = true)
#  |-- _c2: string (nullable = true)
#  |-- _c3: string (nullable = true)
#  |-- _c4: string (nullable = true)
#  |-- _c5: string (nullable = true)
#  |-- _c6: string (nullable = true)

# %%
sales = spark.read.format('csv')\
    .option('header',True).option('inferSchema',True)\
    .load(r"C:\Users\user1\pyspark_env\sales_data_clean.csv")

# %%
sales.printSchema()
# Out:
# root
#  |-- sale_id: integer (nullable = true)
#  |-- date: date (nullable = true)
#  |-- region: string (nullable = true)
#  |-- product: string (nullable = true)
#  |-- quantity: integer (nullable = true)
#  |-- unit_price: double (nullable = true)
#  |-- total_sales: double (nullable = true)

# %%
sales.show()
# Out:
# +-------+----------+------+--------+--------+----------+-----------+
# |sale_id|      date|region| product|quantity|unit_price|total_sales|
# +-------+----------+------+--------+--------+----------+-----------+
# |      1|2025-01-02|  East| Monitor|       8|  42106.76|  336854.08|
# |      2|2025-01-03|  East|   Mouse|       3|   7448.26|   22344.78|
# |      3|2025-01-04|  East| Printer|       4|  10429.24|   41716.96|
# |      4|2025-01-05|  East| Printer|       2|  50678.91|  101357.82|
# |      5|2025-01-06| South|   Mouse|       5|  43414.96|   217074.8|
# |      6|2025-01-07| South| Printer|       9|  20740.43|  186663.87|
# |      7|2025-01-08|  East|   Mouse|       3|  27081.11|   81243.33|
# |      8|2025-01-09|  West|  Laptop|       3|  60265.86|  180797.58|
# |      9|2025-01-10|  East| Printer|       9|   5021.09|   45189.81|
# |     10|2025-01-11|  West|  Laptop|       2|  27286.45|    54572.9|
# |     11|2025-01-12| South| Printer|       2|   48054.2|    96108.4|
# ...

# %%
sales.show(3)
# Out:
# +-------+----------+------+-------+--------+----------+-----------+
# |sale_id|      date|region|product|quantity|unit_price|total_sales|
# +-------+----------+------+-------+--------+----------+-----------+
# |      1|2025-01-02|  East|Monitor|       8|  42106.76|  336854.08|
# |      2|2025-01-03|  East|  Mouse|       3|   7448.26|   22344.78|
# |      3|2025-01-04|  East|Printer|       4|  10429.24|   41716.96|
# +-------+----------+------+-------+--------+----------+-----------+
# only showing top 3 rows

# %%
sales.show(5)
# Out:
# +-------+----------+------+-------+--------+----------+-----------+
# |sale_id|      date|region|product|quantity|unit_price|total_sales|
# +-------+----------+------+-------+--------+----------+-----------+
# |      1|2025-01-02|  East|Monitor|       8|  42106.76|  336854.08|
# |      2|2025-01-03|  East|  Mouse|       3|   7448.26|   22344.78|
# |      3|2025-01-04|  East|Printer|       4|  10429.24|   41716.96|
# |      4|2025-01-05|  East|Printer|       2|  50678.91|  101357.82|
# |      5|2025-01-06| South|  Mouse|       5|  43414.96|   217074.8|
# +-------+----------+------+-------+--------+----------+-----------+
# only showing top 5 rows

# %%
sa=sales.select('sale_id','unit_price')

# %%
sa.printSchema()
# Out:
# root
#  |-- sale_id: integer (nullable = true)
#  |-- unit_price: double (nullable = true)

# %%
sales.printSchema()
# Out:
# root
#  |-- sale_id: integer (nullable = true)
#  |-- date: date (nullable = true)
#  |-- region: string (nullable = true)
#  |-- product: string (nullable = true)
#  |-- quantity: integer (nullable = true)
#  |-- unit_price: double (nullable = true)
#  |-- total_sales: double (nullable = true)

# %%
sa.show()
# Out:
# +-------+----------+
# |sale_id|unit_price|
# +-------+----------+
# |      1|  42106.76|
# |      2|   7448.26|
# |      3|  10429.24|
# |      4|  50678.91|
# |      5|  43414.96|
# |      6|  20740.43|
# |      7|  27081.11|
# |      8|  60265.86|
# |      9|   5021.09|
# |     10|  27286.45|
# |     11|   48054.2|
# |     12|  42894.77|
# |     13|  18485.21|
# |     14|  30048.33|
# |     15|  13347.38|
# |     16|  27962.94|
# |     17|  67301.46|
# |     18|   38008.6|
# |     19|  20024.95|
# |     20|  21091.01|
# +-------+----------+
# only showing top 20 rows

# %%
type(sa)
# Out:
# pyspark.sql.dataframe.DataFrame

# %%
sa=sales.select(sales['sale_id'],sales['unit_price'])
sa.show()
# Out:
# +-------+----------+
# |sale_id|unit_price|
# +-------+----------+
# |      1|  42106.76|
# |      2|   7448.26|
# |      3|  10429.24|
# |      4|  50678.91|
# |      5|  43414.96|
# |      6|  20740.43|
# |      7|  27081.11|
# |      8|  60265.86|
# |      9|   5021.09|
# |     10|  27286.45|
# |     11|   48054.2|
# |     12|  42894.77|
# |     13|  18485.21|
# |     14|  30048.33|
# |     15|  13347.38|
# |     16|  27962.94|
# |     17|  67301.46|
# |     18|   38008.6|
# |     19|  20024.95|
# |     20|  21091.01|
# +-------+----------+
# only showing top 20 rows

# %%
type(sa)
# Out:
# pyspark.sql.dataframe.DataFrame

# %%
sa=sales.select(sales.sale_id,sales.unit_price,sales.quantity)
sa.show()
# Out:
# +-------+----------+--------+
# |sale_id|unit_price|quantity|
# +-------+----------+--------+
# |      1|  42106.76|       8|
# |      2|   7448.26|       3|
# |      3|  10429.24|       4|
# |      4|  50678.91|       2|
# |      5|  43414.96|       5|
# |      6|  20740.43|       9|
# |      7|  27081.11|       3|
# |      8|  60265.86|       3|
# |      9|   5021.09|       9|
# |     10|  27286.45|       2|
# |     11|   48054.2|       2|
# |     12|  42894.77|       7|
# |     13|  18485.21|       1|
# |     14|  30048.33|       2|
# |     15|  13347.38|       4|
# |     16|  27962.94|       2|
# |     17|  67301.46|       9|
# |     18|   38008.6|       2|
# |     19|  20024.95|       9|
# |     20|  21091.01|       9|
# +-------+----------+--------+
# only showing top 20 rows

# %%
sa.show()
# Out:
# +-------+----------+--------+
# |sale_id|unit_price|quantity|
# +-------+----------+--------+
# |      1|  42106.76|       8|
# |      2|   7448.26|       3|
# |      3|  10429.24|       4|
# |      4|  50678.91|       2|
# |      5|  43414.96|       5|
# |      6|  20740.43|       9|
# |      7|  27081.11|       3|
# |      8|  60265.86|       3|
# |      9|   5021.09|       9|
# |     10|  27286.45|       2|
# |     11|   48054.2|       2|
# |     12|  42894.77|       7|
# |     13|  18485.21|       1|
# |     14|  30048.33|       2|
# |     15|  13347.38|       4|
# |     16|  27962.94|       2|
# |     17|  67301.46|       9|
# |     18|   38008.6|       2|
# |     19|  20024.95|       9|
# |     20|  21091.01|       9|
# +-------+----------+--------+
# only showing top 20 rows

# %%
qty=sales.where(sales['quantity'] >6).select(sales.sale_id,sales.unit_price,sales.quantity)
qty.show(30)
# Out:
# +-------+----------+--------+
# |sale_id|unit_price|quantity|
# +-------+----------+--------+
# |      1|  42106.76|       8|
# |      6|  20740.43|       9|
# |      9|   5021.09|       9|
# |     12|  42894.77|       7|
# |     17|  67301.46|       9|
# |     19|  20024.95|       9|
# |     20|  21091.01|       9|
# |     21|  69088.64|       9|
# |     22|    883.79|       8|
# |     25|  59577.68|       7|
# |     30|  49891.07|       9|
# |     33|  42507.01|       7|
# |     36|   7831.85|       9|
# |     38|  62778.35|       7|
# |     41|  34195.68|       9|
# |     42|  66032.22|       8|
# |     49|  53432.56|       7|
# |     52|  22794.21|       9|
# |     57|  10057.71|       8|
# |     58|  15030.48|       9|
# |     60|  36406.19|       9|
# |     63|  24770.07|       9|
# |     65|  59639.53|       8|
# |     67|  46613.37|       9|
# |     69|  12726.81|       9|
# |     85|  49322.64|       9|
# |     86|  29674.77|       7|
# |     87|  63970.22|       8|
# ...

# %%
ob=qty.orderBy('quantity')
ob.show(30)
# Out:
# +-------+----------+--------+
# |sale_id|unit_price|quantity|
# +-------+----------+--------+
# |     12|  42894.77|       7|
# |     25|  59577.68|       7|
# |     33|  42507.01|       7|
# |     38|  62778.35|       7|
# |     49|  53432.56|       7|
# |     86|  29674.77|       7|
# |     99|  17934.81|       7|
# |    100|  30267.86|       7|
# |      1|  42106.76|       8|
# |     22|    883.79|       8|
# |     42|  66032.22|       8|
# |     57|  10057.71|       8|
# |     65|  59639.53|       8|
# |     87|  63970.22|       8|
# |      6|  20740.43|       9|
# |      9|   5021.09|       9|
# |     17|  67301.46|       9|
# |     19|  20024.95|       9|
# |     20|  21091.01|       9|
# |     21|  69088.64|       9|
# |     30|  49891.07|       9|
# |     36|   7831.85|       9|
# |     41|  34195.68|       9|
# |     52|  22794.21|       9|
# |     58|  15030.48|       9|
# |     60|  36406.19|       9|
# |     63|  24770.07|       9|
# |     67|  46613.37|       9|
# ...

# %%
qty=sales.orderBy('quantity')
qty.show(30)
type(qty)
# Out:
# +-------+----------+------+--------+--------+----------+-----------+
# |sale_id|      date|region| product|quantity|unit_price|total_sales|
# +-------+----------+------+--------+--------+----------+-----------+
# |     13|2025-01-14|  West|Keyboard|       1|  18485.21|   18485.21|
# |     23|2025-01-24|  East|Keyboard|       1|  49938.27|   49938.27|
# |     26|2025-01-27|  West|   Mouse|       1|   4917.31|    4917.31|
# |     29|2025-01-30| North|Keyboard|       1|   50660.2|    50660.2|
# |     39|2025-02-09|  East|  Laptop|       1|  16341.49|   16341.49|
# |     46|2025-02-16| North|  Laptop|       1|  68374.74|   68374.74|
# |     47|2025-02-17|  West| Printer|       1|  44587.42|   44587.42|
# |     56|2025-02-26|  West|  Laptop|       1|  28131.26|   28131.26|
# |     61|2025-03-03| North|   Mouse|       1|   6970.64|    6970.64|
# |     71|2025-03-13|  West|Keyboard|       1|  21910.23|   21910.23|
# |     75|2025-03-17| North| Monitor|       1|  14069.39|   14069.39|
# ...

# %%
sales.orderBy(sales['quantity'].desc()).show(30)
# Out:
# +-------+----------+------+--------+--------+----------+-----------+
# |sale_id|      date|region| product|quantity|unit_price|total_sales|
# +-------+----------+------+--------+--------+----------+-----------+
# |      6|2025-01-07| South| Printer|       9|  20740.43|  186663.87|
# |      9|2025-01-10|  East| Printer|       9|   5021.09|   45189.81|
# |     17|2025-01-18|  West| Monitor|       9|  67301.46|  605713.14|
# |     19|2025-01-20|  West|   Mouse|       9|  20024.95|  180224.55|
# |     20|2025-01-21|  West| Printer|       9|  21091.01|  189819.09|
# |     21|2025-01-22| North|  Laptop|       9|  69088.64|  621797.76|
# |     30|2025-01-31|  East|Keyboard|       9|  49891.07|  449019.63|
# |     67|2025-03-09| South|Keyboard|       9|  46613.37|  419520.33|
# |     36|2025-02-06| South|   Mouse|       9|   7831.85|   70486.65|
# |     41|2025-02-11|  East|Keyboard|       9|  34195.68|  307761.12|
# |     52|2025-02-22|  East|  Laptop|       9|  22794.21|  205147.89|
# ...

# %%
gp_pr=sales.groupby(sales['product']).count().show()
# Out:
# +--------+-----+
# | product|count|
# +--------+-----+
# |  Laptop|   24|
# |   Mouse|   22|
# | Printer|   20|
# |Keyboard|   20|
# | Monitor|   14|
# +--------+-----+

# %%
gp_region=sales.groupby(sales['product'],sales['region']).count().show()
type(gp_region)
# Out:
# +--------+------+-----+
# | product|region|count|
# +--------+------+-----+
# | Printer|  West|    6|
# |  Laptop|  East|    6|
# | Monitor|  West|    5|
# | Monitor| North|    4|
# |Keyboard|  East|   10|
# |Keyboard| North|    4|
# |Keyboard|  West|    3|
# | Monitor|  East|    5|
# | Printer|  East|    5|
# |   Mouse| South|    5|
# |  Laptop| North|    3|
# |   Mouse| North|    3|
# |Keyboard| South|    3|
# |   Mouse|  East|    8|
# |   Mouse|  West|    6|
# | Printer| North|    2|
# |  Laptop| South|    6|
# | Printer| South|    7|
# |  Laptop|  West|    9|
# +--------+------+-----+
# NoneType

# %%
gp_region.where(gp_region['count']>5).show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[76], line 1
# ----> 1 gp_region.where(gp_region['count']>5).show()
#
# AttributeError: 'NoneType' object has no attribute 'where'

# %%
qty.show()
# Out:
# +-------+----------+------+--------+--------+----------+-----------+
# |sale_id|      date|region| product|quantity|unit_price|total_sales|
# +-------+----------+------+--------+--------+----------+-----------+
# |     46|2025-02-16| North|  Laptop|       1|  68374.74|   68374.74|
# |     98|2025-04-09| South|Keyboard|       1|  28218.05|   28218.05|
# |     47|2025-02-17|  West| Printer|       1|  44587.42|   44587.42|
# |     13|2025-01-14|  West|Keyboard|       1|  18485.21|   18485.21|
# |     26|2025-01-27|  West|   Mouse|       1|   4917.31|    4917.31|
# |     29|2025-01-30| North|Keyboard|       1|   50660.2|    50660.2|
# |     39|2025-02-09|  East|  Laptop|       1|  16341.49|   16341.49|
# |     23|2025-01-24|  East|Keyboard|       1|  49938.27|   49938.27|
# |     56|2025-02-26|  West|  Laptop|       1|  28131.26|   28131.26|
# |     61|2025-03-03| North|   Mouse|       1|   6970.64|    6970.64|
# |     71|2025-03-13|  West|Keyboard|       1|  21910.23|   21910.23|
# ...

# %%
gp_reg=qty.groupby('region','product').count()
type(gp_reg)
# Out:
# pyspark.sql.dataframe.DataFrame

# %%
gp_reg.show()
# Out:
# +------+--------+-----+
# |region| product|count|
# +------+--------+-----+
# | North|  Laptop|    3|
# | South|   Mouse|    5|
# |  West| Printer|    6|
# | South|Keyboard|    3|
# |  East|  Laptop|    6|
# |  West|   Mouse|    6|
# | North|Keyboard|    4|
# | North| Printer|    2|
# | North|   Mouse|    3|
# |  West|Keyboard|    3|
# |  West| Monitor|    5|
# |  East|   Mouse|    8|
# |  East| Monitor|    5|
# | South| Printer|    7|
# |  East| Printer|    5|
# |  East|Keyboard|   10|
# | South|  Laptop|    6|
# | North| Monitor|    4|
# |  West|  Laptop|    9|
# +------+--------+-----+

# %%
gp_reg.printSchema()
# Out:
# root
#  |-- region: string (nullable = true)
#  |-- product: string (nullable = true)
#  |-- count: long (nullable = false)

# %%
gp_reg.where(gp_reg['count'] >5).show()
# Out:
# +------+--------+-----+
# |region| product|count|
# +------+--------+-----+
# |  West| Printer|    6|
# |  East|  Laptop|    6|
# |  West|   Mouse|    6|
# |  East|   Mouse|    8|
# | South| Printer|    7|
# |  East|Keyboard|   10|
# | South|  Laptop|    6|
# |  West|  Laptop|    9|
# +------+--------+-----+

# %%
type(sales)
# Out:
# pyspark.sql.dataframe.DataFrame

# %%
sales.printSchema()
# Out:
# root
#  |-- sale_id: integer (nullable = true)
#  |-- date: date (nullable = true)
#  |-- region: string (nullable = true)
#  |-- product: string (nullable = true)
#  |-- quantity: integer (nullable = true)
#  |-- unit_price: double (nullable = true)
#  |-- total_sales: double (nullable = true)

# %%
sales.show()
# Out:
# +-------+----------+------+--------+--------+----------+-----------+
# |sale_id|      date|region| product|quantity|unit_price|total_sales|
# +-------+----------+------+--------+--------+----------+-----------+
# |      1|2025-01-02|  East| Monitor|       8|  42106.76|  336854.08|
# |      2|2025-01-03|  East|   Mouse|       3|   7448.26|   22344.78|
# |      3|2025-01-04|  East| Printer|       4|  10429.24|   41716.96|
# |      4|2025-01-05|  East| Printer|       2|  50678.91|  101357.82|
# |      5|2025-01-06| South|   Mouse|       5|  43414.96|   217074.8|
# |      6|2025-01-07| South| Printer|       9|  20740.43|  186663.87|
# |      7|2025-01-08|  East|   Mouse|       3|  27081.11|   81243.33|
# |      8|2025-01-09|  West|  Laptop|       3|  60265.86|  180797.58|
# |      9|2025-01-10|  East| Printer|       9|   5021.09|   45189.81|
# |     10|2025-01-11|  West|  Laptop|       2|  27286.45|    54572.9|
# |     11|2025-01-12| South| Printer|       2|   48054.2|    96108.4|
# ...

# %%
discount=sales.withColumn("discnt",sales['total_sales'] - 0.10)

# %%
sales.show()
# Out:
# +-------+----------+------+--------+--------+----------+-----------+
# |sale_id|      date|region| product|quantity|unit_price|total_sales|
# +-------+----------+------+--------+--------+----------+-----------+
# |      1|2025-01-02|  East| Monitor|       8|  42106.76|  336854.08|
# |      2|2025-01-03|  East|   Mouse|       3|   7448.26|   22344.78|
# |      3|2025-01-04|  East| Printer|       4|  10429.24|   41716.96|
# |      4|2025-01-05|  East| Printer|       2|  50678.91|  101357.82|
# |      5|2025-01-06| South|   Mouse|       5|  43414.96|   217074.8|
# |      6|2025-01-07| South| Printer|       9|  20740.43|  186663.87|
# |      7|2025-01-08|  East|   Mouse|       3|  27081.11|   81243.33|
# |      8|2025-01-09|  West|  Laptop|       3|  60265.86|  180797.58|
# |      9|2025-01-10|  East| Printer|       9|   5021.09|   45189.81|
# |     10|2025-01-11|  West|  Laptop|       2|  27286.45|    54572.9|
# |     11|2025-01-12| South| Printer|       2|   48054.2|    96108.4|
# ...

# %%
discount.show()
# Out:
# +-------+----------+------+--------+--------+----------+-----------+------------------+
# |sale_id|      date|region| product|quantity|unit_price|total_sales|            discnt|
# +-------+----------+------+--------+--------+----------+-----------+------------------+
# |      1|2025-01-02|  East| Monitor|       8|  42106.76|  336854.08|336853.98000000004|
# |      2|2025-01-03|  East|   Mouse|       3|   7448.26|   22344.78|          22344.68|
# |      3|2025-01-04|  East| Printer|       4|  10429.24|   41716.96|          41716.86|
# |      4|2025-01-05|  East| Printer|       2|  50678.91|  101357.82|         101357.72|
# |      5|2025-01-06| South|   Mouse|       5|  43414.96|   217074.8|217074.69999999998|
# |      6|2025-01-07| South| Printer|       9|  20740.43|  186663.87|         186663.77|
# |      7|2025-01-08|  East|   Mouse|       3|  27081.11|   81243.33|          81243.23|
# |      8|2025-01-09|  West|  Laptop|       3|  60265.86|  180797.58|180797.47999999998|
# ...

# %%
p_name=discount.withColumnRenamed('product','Product_Name')

# %%
discount.show()
# Out:
# +-------+----------+------+--------+--------+----------+-----------+------------------+
# |sale_id|      date|region| product|quantity|unit_price|total_sales|            discnt|
# +-------+----------+------+--------+--------+----------+-----------+------------------+
# |      1|2025-01-02|  East| Monitor|       8|  42106.76|  336854.08|336853.98000000004|
# |      2|2025-01-03|  East|   Mouse|       3|   7448.26|   22344.78|          22344.68|
# |      3|2025-01-04|  East| Printer|       4|  10429.24|   41716.96|          41716.86|
# |      4|2025-01-05|  East| Printer|       2|  50678.91|  101357.82|         101357.72|
# |      5|2025-01-06| South|   Mouse|       5|  43414.96|   217074.8|217074.69999999998|
# |      6|2025-01-07| South| Printer|       9|  20740.43|  186663.87|         186663.77|
# |      7|2025-01-08|  East|   Mouse|       3|  27081.11|   81243.33|          81243.23|
# |      8|2025-01-09|  West|  Laptop|       3|  60265.86|  180797.58|180797.47999999998|
# ...

# %%
p_name.show()
# Out:
# +-------+----------+------+------------+--------+----------+-----------+------------------+
# |sale_id|      date|region|Product_Name|quantity|unit_price|total_sales|            discnt|
# +-------+----------+------+------------+--------+----------+-----------+------------------+
# |      1|2025-01-02|  East|     Monitor|       8|  42106.76|  336854.08|336853.98000000004|
# |      2|2025-01-03|  East|       Mouse|       3|   7448.26|   22344.78|          22344.68|
# |      3|2025-01-04|  East|     Printer|       4|  10429.24|   41716.96|          41716.86|
# |      4|2025-01-05|  East|     Printer|       2|  50678.91|  101357.82|         101357.72|
# |      5|2025-01-06| South|       Mouse|       5|  43414.96|   217074.8|217074.69999999998|
# |      6|2025-01-07| South|     Printer|       9|  20740.43|  186663.87|         186663.77|
# |      7|2025-01-08|  East|       Mouse|       3|  27081.11|   81243.33|          81243.23|
# ...

# %%
p_name.describe().show()
# Out:
# +-------+------------------+------+------------+------------------+-----------------+------------------+------------------+
# |summary|           sale_id|region|Product_Name|          quantity|       unit_price|       total_sales|            discnt|
# +-------+------------------+------+------------+------------------+-----------------+------------------+------------------+
# |  count|               100|   100|         100|               100|              100|               100|               100|
# |   mean|              50.5|  NULL|        NULL|              4.77|34664.10420000001|167557.57240000003|167557.47239999997|
# | stddev|29.011491975882016|  NULL|        NULL|2.7260620208304407|19088.47061434354|144167.33258819583|144167.33258819583|
# |    min|                 1|  East|    Keyboard|                 1|           883.79|           4917.31|           4917.21|
# ...
