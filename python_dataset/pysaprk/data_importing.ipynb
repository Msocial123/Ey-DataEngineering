# %%
import os
os.environ["SPARK_HOME"] = r"C:\Spark\spark-3.5.7-bin-hadoop3"
os.environ["HADOOP_HOME"] = r"C:\hadoop"
os.environ["PYSPARK_PYTHON"] = "python"
os.environ["JAVA_HOME"] = r"C:\Program Files\Eclipse Adoptium\jdk-17.0.17.10-hotspot"
 
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName("importing data").master("local[*]").getOrCreate()
 
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://DATA-AWS:4041">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.7</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>importing data</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
csv_path=r"C:\Users\user1\pyspark_env\employees.csv" #importing the csv file

# %%
df_csv=spark.read.option("header",True).option("inferschema",True).csv(csv_path)
print("csv file loaded")
df_csv.show(1)
# df_csv.printSchema()
# Out:
# csv file loaded
# +------+----+----+------+--------+
# |emp_id|name|dept|salary|location|
# +------+----+----+------+--------+
# |   101|Ravi|  HR| 55000| Chennai|
# +------+----+----+------+--------+
# only showing top 1 row

# %%
spark.

# %%
spark.stop()
print("✅ SparkSession stopped successfully")
# Out:
# ✅ SparkSession stopped successfully
