# %%
import os
os.environ["SPARK_HOME"] = r"C:\Spark\spark-3.5.7-bin-hadoop3"
os.environ["HADOOP_HOME"] = r"C:\hadoop"
os.environ["PYSPARK_PYTHON"] = "python"
os.environ["JAVA_HOME"] = r"C:\Program Files\Eclipse Adoptium\jdk-17.0.17.10-hotspot"
 
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName("PySparkGUIExample").master("local[*]").getOrCreate()
 
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://DATA-AWS:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.7</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>PySparkGUIExample</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
data = [(1,"Alice",20000), (2,"Ramu",100000), (3,"Vimal",52555)]
df = spark.createDataFrame(data, ["Index","Name","Salary"])
df.show()
# Out:
# +-----+-----+------+
# |Index| Name|Salary|
# +-----+-----+------+
# |    1|Alice| 20000|
# |    2| Ramu|100000|
# |    3|Vimal| 52555|
# +-----+-----+------+

# %%
df.printSchema()
# Out:
# root
#  |-- Index: long (nullable = true)
#  |-- Name: string (nullable = true)
#  |-- Salary: long (nullable = true)

# %%
df.collect()
# Out:
# [Row(Index=1, Name='Alice', Salary=20000),
#  Row(Index=2, Name='Ramu', Salary=100000),
#  Row(Index=3, Name='Vimal', Salary=52555)]

# %%
type(df)
# Out:
# pyspark.sql.dataframe.DataFrame
